# %%
import pandas as pd
from sklearn.metrics import classification_report

# %%
# !ls
# Out:
# Constraint_Val.csv                postproc_val.csv
# EDA-Copy1.ipynb                   test_false_pred_final.csv
# EDA.ipynb                         test_false_pred_final_1.csv
# english_test_with_labels.csv      test_false_pred_final_var_1.csv
# post_proc_final-Copy1.ipynb       test_false_pred_final_var_1_1.csv
# post_proc_final-Copy2.ipynb       test_false_pred_var_1.csv
# post_proc_final.ipynb             test_false_pred_var_1_1.csv
# post_proc_final_1.ipynb           test_false_pred_var_2.csv
# post_proc_final_var_1.1.ipynb     test_false_pred_var_2_1.csv
# post_proc_final_var_1.ipynb       val_false_pred_final.csv
# post_proc_var_1.1.ipynb           val_false_pred_final_1.csv
# post_proc_var_1.ipynb             val_false_pred_final_var_1.csv
# post_proc_var_2.1.ipynb           val_false_pred_final_var_1_1.csv
# post_proc_var_2.ipynb             val_false_pred_var_1.csv
# postproc_test.csv                 val_false_pred_var_1_1.csv
# postproc_train.csv                val_false_pred_var_2_1.csv

# %%
train = pd.read_csv('../Post Processing/data/postproc_train.csv')
val = pd.read_csv('../Post Processing/data/postproc_val.csv')
test = pd.read_csv('../Post Processing/data/postproc_test.csv')
test_gt = pd.read_csv('../../data/english_test_with_labels.csv')
val_gt = pd.read_csv('../../data/Constraint_Val.csv')

# %%
def post_proc(row):
    if (row['username_real']>row['username_fake']) & (row['username_real']>0.88):
        return 0
    elif (row['username_real']<row['username_fake']) & (row['username_fake']>0.88):
        return 1
    else:
        if row['class1_pred']>row['class0_pred']:
            return 1
        elif row['class1_pred']<row['class0_pred']:
            return 0

def post_proc1(row):
    if row['class1_pred']>row['class0_pred']:
        return 1
    elif row['class1_pred']<row['class0_pred']:
        return 0

# %%
train['final_pred'] = train.apply(lambda x: post_proc(x), 1)

# %%
print(classification_report(train['label'], train['final_pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3360
#            1       1.00      1.00      1.00      3060
#
#     accuracy                           1.00      6420
#    macro avg       1.00      1.00      1.00      6420
# weighted avg       1.00      1.00      1.00      6420

# %%
val['final_pred'] = val.apply(lambda x: post_proc(x), 1)

# %%
print(classification_report(val['label'], val['final_pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1120
#            1       0.99      0.97      0.98      1020
#
#     accuracy                           0.98      2140
#    macro avg       0.98      0.98      0.98      2140
# weighted avg       0.98      0.98      0.98      2140

# %%
from sklearn.metrics import f1_score,accuracy_score,precision_score,recall_score
print('accuracy : ',accuracy_score(val['label'], val['final_pred']))
print('f1_score : ',f1_score(val['label'], val['final_pred'],average='micro'))
print('precision_score : ',precision_score(val['label'], val['final_pred'],average='micro'))
print('recall_score : ',recall_score(val['label'], val['final_pred'],average='micro'))
# Out:
# accuracy :  0.983177570093458
# f1_score :  0.983177570093458
# precision_score :  0.983177570093458
# recall_score :  0.983177570093458

# %%
test['final_pred'] = test.apply(lambda x: post_proc(x), 1)

# %%
print(classification_report(test['label'], test['final_pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1120
#            1       0.99      0.97      0.98      1020
#
#     accuracy                           0.98      2140
#    macro avg       0.98      0.98      0.98      2140
# weighted avg       0.98      0.98      0.98      2140

# %%
from sklearn.metrics import f1_score,accuracy_score,precision_score,recall_score
print('accuracy : ',accuracy_score(test['label'], test['final_pred']))
print('f1_score : ',f1_score(test['label'], test['final_pred'],average='micro'))
print('precision_score : ',precision_score(test['label'], test['final_pred'],average='micro'))
print('recall_score : ',recall_score(test['label'], test['final_pred'],average='micro'))
# Out:
# accuracy :  0.9836448598130841
# f1_score :  0.9836448598130841
# precision_score :  0.9836448598130841
# recall_score :  0.9836448598130841

# %% [markdown]
# ## Get False Pred samples

# %%
val_false_pred = val[val.final_pred!=val.label]

# %%
pd.merge(val_false_pred, val_gt, left_index=True, right_index=True)
# Out:
#       class0_pred  class1_pred  username_real  username_fake  domain_real  \
# 61       0.753929     0.246071       0.000000       0.000000     0.000000
# 120      0.549750     0.450250       0.000000       0.000000     0.000000
# 145      0.694918     0.305082       0.000000       0.000000     0.000000
# 148      0.606062     0.393938       0.000000       0.000000     0.000000
# 312      0.516835     0.483165       0.000000       0.000000     0.000000
# 438      0.846456     0.153544       0.000000       0.000000     0.000000
# 496      0.914677     0.085323       0.000000       0.000000     0.000000
# 609      0.260771     0.739229       0.000000       0.000000     1.000000
# 734      0.880232     0.119768       0.000000       0.000000     0.000000
# 738      0.998551     0.001449       0.000000       1.000000     1.000000
# 757      0.996346     0.003654       0.000000       0.000000     0.000000
# 769      0.250243     0.749757       0.000000       0.000000     1.000000
# 838      0.933194     0.066806       0.000000       0.000000     0.000000
# 965      0.936419     0.063581       0.000000       0.000000     0.000000
# 1061     0.002517     0.997483       0.000000       0.000000     1.000000
# 1213     0.473971     0.526029       0.000000       0.000000     1.000000
# 1312     0.250292     0.749708       1.000000       0.000000     0.838903
# 1364     0.543479     0.456521       0.000000       0.000000     0.000000
# 1440     0.756119     0.243881       0.000000       0.000000     0.000000
# 1518     0.581829     0.418171       0.000000       0.000000     0.000000
# 1521     0.411527     0.588473       0.000000       0.000000     0.000000
# 1586     0.998246     0.001754       0.000000       0.000000     0.000000
# 1591     0.995330     0.004670       0.026667       0.773333     0.838903
# 1769     0.420238     0.579762       0.495146       0.004854     0.000000
# 1790     0.941059     0.058941       0.000000       0.000000     0.000000
# 1850     0.829159     0.170841       0.000000       0.000000     0.000000
# 1870     0.511586     0.488414       0.000000       0.000000     0.838903
# 1908     0.782819     0.217181       0.000000       0.000000     0.000000
# 1920     0.918278     0.081722       0.000000       0.000000     0.000000
# 1930     0.620791     0.379209       0.000000       0.000000     0.000000
# 1962     0.687295     0.312705       0.000000       0.000000     0.000000
# 1994     0.761741     0.238259       0.000000       0.000000     0.838903
# 2004     0.511920     0.488080       0.000000       0.000000     0.000000
# 2051     0.963755     0.036245       0.000000       0.000000     0.000000
# 2086     0.750133     0.249867       0.000000       1.000000     0.000000
# 2090     0.397039     0.602961       0.000000       0.000000     1.000000
#
#       domain_fake  label_x  final_pred    id  \
# 61       0.000000        1           0    62
# 120      1.000000        1           0   121
# 145      1.000000        1           0   146
# 148      1.000000        1           0   149
# 312      1.000000        1           0   313
# 438      1.000000        1           0   439
# 496      1.000000        1           0   497
# 609      0.000000        0           1   610
# 734      1.000000        1           0   735
# 738      0.000000        0           1   739
# 757      0.000000        1           0   758
# 769      0.000000        0           1   770
# 838      1.000000        1           0   839
# 965      1.000000        1           0   966
# 1061     0.000000        0           1  1062
# 1213     0.000000        0           1  1214
# 1312     0.161097        1           0  1313
# 1364     0.000000        1           0  1365
# 1440     1.000000        1           0  1441
# 1518     0.000000        1           0  1519
# 1521     0.000000        0           1  1522
# 1586     1.000000        1           0  1587
# 1591     0.161097        1           0  1592
# 1769     0.000000        0           1  1770
# 1790     0.000000        1           0  1791
# 1850     1.000000        1           0  1851
# 1870     0.161097        1           0  1871
# 1908     1.000000        1           0  1909
# 1920     0.000000        1           0  1921
# 1930     0.000000        1           0  1931
# 1962     1.000000        1           0  1963
# 1994     0.161097        1           0  1995
# 2004     0.000000        1           0  2005
# 2051     0.000000        1           0  2052
# 2086     0.000000        0           1  2087
# 2090     0.000000        0           1  2091
#
#                                                   tweet label_y
# 61    The Global #dietarysupplements market is antic...    fake
# 120   WHO reports record daily increase in global co...    fake
# 145   There is no evidence that children have died b...    fake
# 148   The 2005 study found that chloroquine was effe...    fake
# 312   Florida Gov. Ron DeSantis said schoolchildren ...    fake
# 438   The N95 respirator offers the most protection ...    fake
# 496   In objection to WA's border closures @CliveFPa...    fake
# 609   How deadly is the coronavirus #COVID19? Scient...    real
# 734   Health officials caution against the use of ch...    fake
# 738   FDA chief @SteveFDA rejects the president’s im...    real
# 757   How has alcohol consumption changed during loc...    fake
# 769   As for the Russian COVID vaccine Fauci is amon...    real
# 838   #VitaminD is now in focus to prevent #Coronavi...    fake
# 965   We're still a long way away from herd immunity...    fake
# 1061  #ZuckOff #TakeItFromADoctor and a video with f...    real
# 1213  Black Americans are hospitalized for coronavir...    real
# 1312  Sources confirm COVID 19 Vaccine Needs at leas...    fake
# 1364  Vitamin D can help reduce coronavirus risk by ...    fake
# 1440  Children do contract the coronavirus but curre...    fake
# 1518  process has asked sbi and business oil prices ...    fake
# 1521  The fight against Covid takes warriors. Each a...    real
# 1586  A @Target spokesperson said the company plans ...    fake
# 1591  At this Critical Scenario We need full fledged...    fake
# 1769  @CAALKESHKASLIWA @ICMRDELHI #COVID_19 treatmen...    real
# 1790  3/3 ... at the start was reasonably necessary"...    fake
# 1850  @hapelensrob #Fauci as head of #NIH in 2005 pu...    fake
# 1870  Have you wanted to make a difference during th...    fake
# 1908  While uncomfortable there no evidence that get...    fake
# 1920  Angiotensin-converting enzyme 2 (ACE2): COVID ...    fake
# 1930  If you maintain social distancing indoors ther...    fake
# 1962  WHO expands coronavirus guidance after pressur...    fake
# 1994  #covid19 #coronavirus #coronavirusupdate NYC i...    fake
# 2004  Children in Oregon may be taken away if their ...    fake
# 2051  All Missouri businesses can open Monday May 4 ...    fake
# 2086  In a presser @VP Pence just gave two important...    real
# 2090  The UK government says it has responded well t...    real

# %%
pd.merge(val_false_pred, val_gt, left_index=True, right_index=True).to_csv('../Post Processing/results/val_false_pred_var_2.csv')

# %%
test_false_pred = test[test.final_pred!=test.label]

# %%
pd.merge(test_false_pred, test_gt, left_index=True, right_index=True)
# Out:
#       class0_pred  class1_pred  username_real  username_fake  domain_real  \
# 10       0.732060     0.267940       0.000000       0.000000     0.000000
# 27       0.824448     0.175552       0.000000       0.000000     0.838903
# 184      0.225028     0.774972       0.000000       0.000000     0.000000
# 267      0.670170     0.329830       0.000000       0.000000     0.000000
# 273      0.502039     0.497961       0.000000       0.000000     0.000000
# 277      0.998927     0.001073       0.000000       0.000000     0.000000
# 302      0.003921     0.996079       0.000000       0.000000     1.000000
# 319      0.995932     0.004068       0.000000       0.000000     0.000000
# 349      0.012864     0.987136       0.000000       0.000000     0.000000
# 367      0.876696     0.123304       0.000000       0.000000     0.000000
# 413      0.778312     0.221688       0.000000       0.000000     0.000000
# 466      0.800170     0.199830       0.000000       0.000000     0.000000
# 469      0.729116     0.270884       0.000000       0.000000     0.838903
# 526      0.398637     0.601363       0.000000       0.000000     1.000000
# 540      0.739774     0.260226       0.000000       0.000000     0.000000
# 655      0.401064     0.598936       0.000000       0.000000     1.000000
# 695      0.545628     0.454372       0.000000       0.000000     0.000000
# 728      0.507567     0.492433       0.000000       0.000000     0.000000
# 867      0.804524     0.195476       0.000000       0.000000     0.000000
# 873      0.634749     0.365251       0.000000       0.000000     0.994819
# 882      0.649809     0.350191       0.000000       0.000000     0.000000
# 975      0.512140     0.487860       0.000000       0.000000     0.000000
# 986      0.831067     0.168933       0.000000       0.000000     0.000000
# 1105     0.826940     0.173060       0.000000       0.000000     0.000000
# 1145     0.965703     0.034297       0.000000       0.000000     0.000000
# 1160     0.277451     0.722549       0.000000       0.000000     1.000000
# 1200     0.997680     0.002320       0.000000       0.000000     0.000000
# 1212     0.000389     0.999611       0.962963       0.037037     0.000000
# 1217     0.011369     0.988631       0.000000       0.000000     1.000000
# 1231     0.558890     0.441110       0.000000       0.000000     0.000000
# 1249     0.884838     0.115162       0.000000       0.000000     0.000000
# 1564     0.731947     0.268053       0.000000       0.000000     0.000000
# 1795     0.998827     0.001173       0.000000       0.000000     0.838903
# 1937     0.722304     0.277696       0.000000       0.000000     0.000000
# 2044     0.998893     0.001107       0.000000       0.000000     0.838903
#
#       domain_fake  label_x  final_pred    id  \
# 10       0.000000        1           0    11
# 27       0.161097        1           0    28
# 184      0.000000        0           1   185
# 267      0.000000        1           0   268
# 273      0.000000        1           0   274
# 277      1.000000        1           0   278
# 302      0.000000        0           1   303
# 319      0.000000        1           0   320
# 349      0.000000        0           1   350
# 367      1.000000        1           0   368
# 413      0.000000        1           0   414
# 466      1.000000        1           0   467
# 469      0.161097        1           0   470
# 526      0.000000        0           1   527
# 540      1.000000        1           0   541
# 655      0.000000        0           1   656
# 695      0.000000        1           0   696
# 728      0.000000        1           0   729
# 867      0.000000        1           0   868
# 873      0.005181        1           0   874
# 882      1.000000        1           0   883
# 975      0.000000        1           0   976
# 986      0.000000        1           0   987
# 1105     0.000000        1           0  1106
# 1145     1.000000        1           0  1146
# 1160     0.000000        0           1  1161
# 1200     1.000000        1           0  1201
# 1212     0.000000        1           0  1213
# 1217     0.000000        0           1  1218
# 1231     1.000000        1           0  1232
# 1249     1.000000        1           0  1250
# 1564     0.000000        1           0  1565
# 1795     0.161097        1           0  1796
# 1937     0.000000        1           0  1938
# 2044     0.161097        1           0  2045
#
#                                                   tweet label_y
# 10    Two interesting correlations:\n\n1) Children t...    fake
# 27    Govt has added #Corona disease in all existing...    fake
# 184   *DNA Vaccine: injecting genetic material into ...    real
# 267   Keep your newborn more than 6 feet away from y...    fake
# 273   Strange coincidence that all worst affected Co...    fake
# 277   This year Election Night could be chaotic. In ...    fake
# 302   Donald Trump has claimed he "up-played" the se...    real
# 319   @carenkarpenter There are big studies and find...    fake
# 349   “She drew a difference between these protests ...    real
# 367   Bank of America said the funds will go to prog...    fake
# 413   Early action and social trust are among the re...    fake
# 466   Florida Gov. Ron DeSantis said today kids are ...    fake
# 469   @geoallison Today's official figures.\n\nA rec...    fake
# 526   Scientists ask: Without trial data how can we ...    real
# 540   A paper estimating that 266796 COVID-19 cases ...    fake
# 655   Coronavirus: Donald Trump ignores COVID-19 rul...    real
# 695   For its must-read coronavirus coverage The Atl...    fake
# 728   Mycoplasma pneumonia can be treated with quino...    fake
# 867   there is variation in mortality and infection ...    fake
# 873   RT @Poynter: Remember no coronavirus vaccine i...    fake
# 882   Trump says coronavirus task force will keep wo...    fake
# 975   @NoWackyScience @__ice9 @ydeigin ..for efficie...    fake
# 986   Government's roadmap to ease Covid-19 restrict...    fake
# 1105  I've decided to opt out of the KCL symptoms tr...    fake
# 1145  Home gyms struggle to retain members after ear...    fake
# 1160  Abuse-deterrent oxycontin will not solve the o...    real
# 1200  Coronavirus: new discovery changes things http...    fake
# 1212  “Ministry of AYUSH, Govt. of India suggested t...    fake
# 1217  While farcical disinformation about the corona...    real
# 1231  Oxford coronavirus vaccine is safe and induces...    fake
# 1249  While COVID-19 tests may sometimes produce fal...    fake
# 1564  I'm about to deliver remarks on the Coronaviru...    fake
# 1795  Proud of @BoltsPk team busy in packing stuff f...    fake
# 1937  Despite the COVID-19 pandemic the total number...    fake
# 2044  I know a family of 3 tested positive on #COVID...    fake

# %%
pd.merge(test_false_pred, test_gt, left_index=True, right_index=True).to_csv('../Post Processing/results/test_false_pred_var_2.csv')
